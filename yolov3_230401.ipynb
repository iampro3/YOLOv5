# %% [markdown]
# <a href="https://colab.research.google.com/github/iampro3/YOLOv5/blob/main/yolov3_230401.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## yolov3 :
# -참조 git : https://github.com/eriklindernoren/PyTorch-YOLOv3
# - https://dacon.io/en/codeshare/4557

# %%
pip install tensorflow
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.9/dist-packages (2.12.0)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (2.12.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (0.32.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (2.2.0)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (23.3.3)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (16.0.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from tensorflow) (23.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (1.53.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from tensorflow) (67.6.1)
# Requirement already satisfied: jax>=0.3.15 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (0.4.7)
# Requirement already satisfied: numpy<1.24,>=1.22 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (1.22.4)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (4.5.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (3.8.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: keras<2.13,>=2.12.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (2.12.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (2.12.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.9/dist-packages (from astunparse>=1.6.0->tensorflow) (0.40.0)
# Requirement already satisfied: scipy>=1.7 in /usr/local/lib/python3.9/dist-packages (from jax>=0.3.15->tensorflow) (1.10.1)
# Requirement already satisfied: ml-dtypes>=0.0.3 in /usr/local/lib/python3.9/dist-packages (from jax>=0.3.15->tensorflow) (0.0.4)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.13,>=2.12->tensorflow) (0.7.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.13,>=2.12->tensorflow) (2.17.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.13,>=2.12->tensorflow) (3.4.3)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.13,>=2.12->tensorflow) (0.4.6)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.13,>=2.12->tensorflow) (2.2.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.13,>=2.12->tensorflow) (2.27.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.13,>=2.12->tensorflow) (1.8.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.13,>=2.12->tensorflow) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.9/dist-packages (from markdown>=2.6.8->tensorboard<2.13,>=2.12->tensorflow) (6.1.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (1.26.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (2022.12.7)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.9/dist-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow) (2.1.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.9/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.13,>=2.12->tensorflow) (3.15.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.9/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.9/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.13,>=2.12->tensorflow) (3.2.2)

# %%
# !pip install opencv-python
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.9/dist-packages (4.7.0.72)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.9/dist-packages (from opencv-python) (1.22.4)

# %%
# !git clone https://github.com/eriklindernoren/PyTorch-YOLOv3
# Out:
# fatal: destination path 'PyTorch-YOLOv3' already exists and is not an empty directory.

# %%
cd PyTorch-YOLOv3/
# Out:
# /content/PyTorch-YOLOv3

# %%
# !pip freeze >  requirements.txt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip3 uninstall Pillow -y
# Out:
# Found existing installation: Pillow 9.5.0
# Uninstalling Pillow-9.5.0:
#   Successfully uninstalled Pillow-9.5.0

# %%
# !pip3 install Pillow
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting Pillow
#   Using cached Pillow-9.5.0-cp39-cp39-manylinux_2_28_x86_64.whl (3.4 MB)
# Installing collected packages: Pillow
# Successfully installed Pillow-9.5.0

# %%
cd weights/
# Out:
# /content/PyTorch-YOLOv3/weights

# %%
# !cat /content/PyTorch-YOLOv3/weights/download_weights.sh
# Out:
# #!/bin/bash
# # Download weights for vanilla YOLOv3
# wget -c "https://pjreddie.com/media/files/yolov3.weights" --header "Referer: pjreddie.com"
# # # Download weights for tiny YOLOv3
# wget -c "https://pjreddie.com/media/files/yolov3-tiny.weights" --header "Referer: pjreddie.com"
# # Download weights for backbone network
# wget -c "https://pjreddie.com/media/files/darknet53.conv.74" --header "Referer: pjreddie.com"

# %%
# !bash download_weights.sh
# Out:
# --2023-04-01 09:42:07--  https://pjreddie.com/media/files/yolov3.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 248007048 (237M) [application/octet-stream]
# Saving to: ‘yolov3.weights’
#
# yolov3.weights      100%[===================>] 236.52M  62.2MB/s    in 4.1s
#
# 2023-04-01 09:42:12 (58.2 MB/s) - ‘yolov3.weights’ saved [248007048/248007048]
#
# --2023-04-01 09:42:12--  https://pjreddie.com/media/files/yolov3-tiny.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 35434956 (34M) [application/octet-stream]
# Saving to: ‘yolov3-tiny.weights’
#
# yolov3-tiny.weights 100%[===================>]  33.79M  41.6MB/s    in 0.8s
#
# 2023-04-01 09:42:13 (41.6 MB/s) - ‘yolov3-tiny.weights’ saved [35434956/35434956]
#
# --2023-04-01 09:42:13--  https://pjreddie.com/media/files/darknet53.conv.74
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 162482580 (155M) [application/octet-stream]
# Saving to: ‘darknet53.conv.74’
#
# darknet53.conv.74   100%[===================>] 154.96M  56.7MB/s    in 2.7s
#
# 2023-04-01 09:42:16 (56.7 MB/s) - ‘darknet53.conv.74’ saved [162482580/162482580]

# %% [markdown]
# ## 예측하기
# -상위 폴더로 이동후 detect.py 파일을 실행하겠습니다.
# -경로 설정을 잘해주면 py 파일이 실행이 됩니다.

# %%
cd /content/PyTorch-YOLOv3/pytorchyolo/
# Out:
# /content/PyTorch-YOLOv3/pytorchyolo

# %%
# !pip install poetry -- user
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting poetry
#   Downloading poetry-1.4.1-py3-none-any.whl (222 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 222.3/222.3 KB 6.7 MB/s eta 0:00:00
# ERROR: Could not find a version that satisfies the requirement user (from versions: none)
# ERROR: No matching distribution found for user

# %%
# !pip3 install pytorchyolo --user
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pytorchyolo
#   Downloading pytorchyolo-1.8.0-py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.9/42.9 KB 2.0 MB/s eta 0:00:00
# Requirement already satisfied: torchvision>=0.13.1 in /usr/local/lib/python3.9/dist-packages (from pytorchyolo) (0.14.1+cu116)
# Collecting numpy<2.0.0,>=1.23.4
#   Downloading numpy-1.24.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 58.1 MB/s eta 0:00:00
# Requirement already satisfied: imgaug<0.5.0,>=0.4.0 in /usr/local/lib/python3.9/dist-packages (from pytorchyolo) (0.4.0)
# Requirement already satisfied: tensorboard<3.0.0,>=2.10.0 in /usr/local/lib/python3.9/dist-packages (from pytorchyolo) (2.12.0)
# Requirement already satisfied: matplotlib<4.0.0,>=3.3.3 in /usr/local/lib/python3.9/dist-packages (from pytorchyolo) (3.7.1)
# Requirement already satisfied: Pillow<10.0.0,>=9.1.0 in /usr/local/lib/python3.9/dist-packages (from pytorchyolo) (9.5.0)
# Requirement already satisfied: scipy<2.0,>=1.9 in /usr/local/lib/python3.9/dist-packages (from pytorchyolo) (1.10.1)
# Collecting terminaltables<4.0.0,>=3.1.0
#   Downloading terminaltables-3.1.10-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: torchsummary<2.0.0,>=1.5.1 in /usr/local/lib/python3.9/dist-packages (from pytorchyolo) (1.5.1)
# Requirement already satisfied: urllib3<2.0,>=1.23 in /usr/local/lib/python3.9/dist-packages (from pytorchyolo) (1.26.15)
# Collecting torch<1.13.0,>=1.10.1
#   Downloading torch-1.12.1-cp39-cp39-manylinux1_x86_64.whl (776.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 776.4/776.4 MB 2.2 MB/s eta 0:00:00
# Requirement already satisfied: tqdm<5.0.0,>=4.64.1 in /usr/local/lib/python3.9/dist-packages (from pytorchyolo) (4.65.0)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.9/dist-packages (from imgaug<0.5.0,>=0.4.0->pytorchyolo) (4.7.0.72)
# Requirement already satisfied: Shapely in /usr/local/lib/python3.9/dist-packages (from imgaug<0.5.0,>=0.4.0->pytorchyolo) (2.0.1)
# Requirement already satisfied: scikit-image>=0.14.2 in /usr/local/lib/python3.9/dist-packages (from imgaug<0.5.0,>=0.4.0->pytorchyolo) (0.19.3)
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from imgaug<0.5.0,>=0.4.0->pytorchyolo) (1.16.0)
# Requirement already satisfied: imageio in /usr/local/lib/python3.9/dist-packages (from imgaug<0.5.0,>=0.4.0->pytorchyolo) (2.25.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib<4.0.0,>=3.3.3->pytorchyolo) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib<4.0.0,>=3.3.3->pytorchyolo) (0.11.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib<4.0.0,>=3.3.3->pytorchyolo) (5.12.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib<4.0.0,>=3.3.3->pytorchyolo) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib<4.0.0,>=3.3.3->pytorchyolo) (23.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib<4.0.0,>=3.3.3->pytorchyolo) (1.0.7)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib<4.0.0,>=3.3.3->pytorchyolo) (4.39.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.9/dist-packages (from matplotlib<4.0.0,>=3.3.3->pytorchyolo) (2.8.2)
# Requirement already satisfied: protobuf>=3.19.6 in /usr/local/lib/python3.9/dist-packages (from tensorboard<3.0.0,>=2.10.0->pytorchyolo) (3.20.3)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.9/dist-packages (from tensorboard<3.0.0,>=2.10.0->pytorchyolo) (0.4.6)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard<3.0.0,>=2.10.0->pytorchyolo) (1.8.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.9/dist-packages (from tensorboard<3.0.0,>=2.10.0->pytorchyolo) (2.17.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard<3.0.0,>=2.10.0->pytorchyolo) (2.27.1)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.9/dist-packages (from tensorboard<3.0.0,>=2.10.0->pytorchyolo) (0.40.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.9/dist-packages (from tensorboard<3.0.0,>=2.10.0->pytorchyolo) (1.4.0)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from tensorboard<3.0.0,>=2.10.0->pytorchyolo) (2.2.3)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard<3.0.0,>=2.10.0->pytorchyolo) (67.6.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard<3.0.0,>=2.10.0->pytorchyolo) (0.7.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.9/dist-packages (from tensorboard<3.0.0,>=2.10.0->pytorchyolo) (3.4.3)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.9/dist-packages (from tensorboard<3.0.0,>=2.10.0->pytorchyolo) (1.53.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/dist-packages (from torch<1.13.0,>=1.10.1->pytorchyolo) (4.5.0)
# Collecting torchvision>=0.13.1
#   Downloading torchvision-0.15.1-cp39-cp39-manylinux1_x86_64.whl (6.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 79.6 MB/s eta 0:00:00
#   Downloading torchvision-0.14.1-cp39-cp39-manylinux1_x86_64.whl (24.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.2/24.2 MB 51.2 MB/s eta 0:00:00
#   Downloading torchvision-0.14.0-cp39-cp39-manylinux1_x86_64.whl (24.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.3/24.3 MB 50.7 MB/s eta 0:00:00
#   Downloading torchvision-0.13.1-cp39-cp39-manylinux1_x86_64.whl (19.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.1/19.1 MB 19.4 MB/s eta 0:00:00
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard<3.0.0,>=2.10.0->pytorchyolo) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard<3.0.0,>=2.10.0->pytorchyolo) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard<3.0.0,>=2.10.0->pytorchyolo) (5.3.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<3.0.0,>=2.10.0->pytorchyolo) (1.3.1)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from importlib-resources>=3.2.0->matplotlib<4.0.0,>=3.3.3->pytorchyolo) (3.15.0)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.9/dist-packages (from markdown>=2.6.8->tensorboard<3.0.0,>=2.10.0->pytorchyolo) (6.1.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.21.0->tensorboard<3.0.0,>=2.10.0->pytorchyolo) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.21.0->tensorboard<3.0.0,>=2.10.0->pytorchyolo) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.21.0->tensorboard<3.0.0,>=2.10.0->pytorchyolo) (3.4)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.9/dist-packages (from scikit-image>=0.14.2->imgaug<0.5.0,>=0.4.0->pytorchyolo) (3.0)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.9/dist-packages (from scikit-image>=0.14.2->imgaug<0.5.0,>=0.4.0->pytorchyolo) (2023.3.21)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from scikit-image>=0.14.2->imgaug<0.5.0,>=0.4.0->pytorchyolo) (1.4.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.9/dist-packages (from werkzeug>=1.0.1->tensorboard<3.0.0,>=2.10.0->pytorchyolo) (2.1.2)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.9/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<3.0.0,>=2.10.0->pytorchyolo) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.9/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<3.0.0,>=2.10.0->pytorchyolo) (3.2.2)
# Installing collected packages: torch, terminaltables, numpy, torchvision, pytorchyolo
#   WARNING: The scripts convert-caffe2-to-onnx, convert-onnx-to-caffe2 and torchrun are installed in '/root/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts f2py, f2py3 and f2py3.9 are installed in '/root/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts yolo-detect, yolo-test and yolo-train are installed in '/root/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchtext 0.14.1 requires torch==1.13.1, but you have torch 1.12.1 which is incompatible.
# torchaudio 0.13.1+cu116 requires torch==1.13.1, but you have torch 1.12.1 which is incompatible.
# tensorflow 2.12.0 requires numpy<1.24,>=1.22, but you have numpy 1.24.2 which is incompatible.
# numba 0.56.4 requires numpy<1.24,>=1.18, but you have numpy 1.24.2 which is incompatible.
# Successfully installed numpy-1.24.2 pytorchyolo-1.8.0 terminaltables-3.1.10 torch-1.12.1 torchvision-0.13.1

# %%
cd /content/PyTorch-YOLOv3/
# Out:
# /content/PyTorch-YOLOv3

# %%
# !python3 ./pytorchyolo/detect.py
# Out:
# Environment information:
# System: Linux 5.10.147+
# Not using the poetry package
# Current Commit Hash: 3467db2
# Command line arguments: Namespace(model='config/yolov3.cfg', weights='weights/yolov3.weights', images='data/samples', classes='data/coco.names', output='output', batch_size=1, img_size=416, n_cpu=8, conf_thres=0.5, nms_thres=0.4)
# /root/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:563: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Detecting: 100% 9/9 [00:01<00:00,  5.19it/s]
# Image data/samples/dog.jpg:
# 	+ Label: bicycle | Confidence: 0.9929
# 	+ Label: dog | Confidence: 0.9924
# 	+ Label: truck | Confidence: 0.9401
# Image data/samples/eagle.jpg:
# 	+ Label: bird | Confidence: 0.9969
# Image data/samples/field.jpg:
# 	+ Label: person | Confidence: 0.9999
# 	+ Label: horse | Confidence: 0.9984
# 	+ Label: dog | Confidence: 0.9944
# Image data/samples/giraffe.jpg:
# 	+ Label: giraffe | Confidence: 0.9935
# 	+ Label: zebra | Confidence: 0.9653
# 	+ Label: giraffe | Confidence: 0.6276
# Image data/samples/herd_of_horses.jpg:
# 	+ Label: horse | Confidence: 0.9852
# 	+ Label: horse | Confidence: 0.9740
# 	+ Label: horse | Confidence: 0.9636
# 	+ Label: horse | Confidence: 0.8883
# Image data/samples/messi.jpg:
# 	+ Label: person | Confidence: 0.9974
# 	+ Label: person | Confidence: 0.9954
# 	+ Label: person | Confidence: 0.9802
# 	+ Label: sports ball | Confidence: 0.5254
# Image data/samples/person.jpg:
# 	+ Label: person | Confidence: 0.9961
# 	+ Label: dog | Confidence: 0.9569
# Image data/samples/room.jpg:
# 	+ Label: chair | Confidence: 0.9887
# 	+ Label: chair | Confidence: 0.9126
# 	+ Label: clock | Confidence: 0.8306
# 	+ Label: chair | Confidence: 0.7362
# Image data/samples/street.jpg:
# 	+ Label: car | Confidence: 0.9997
# 	+ Label: car | Confidence: 0.9928
# 	+ Label: car | Confidence: 0.9913
# 	+ Label: car | Confidence: 0.9832
# 	+ Label: car | Confidence: 0.9791
# 	+ Label: car | Confidence: 0.9490
# 	+ Label: traffic light | Confidence: 0.9269
# 	+ Label: car | Confidence: 0.6887
# 	+ Label: car | Confidence: 0.6186
# 	+ Label: truck | Confidence: 0.5215
# 	+ Label: fire hydrant | Confidence: 0.5015
# ---- Detections were saved to: 'output' ----

# %%
ls -al /content/PyTorch-YOLOv3/data/samples/
# Out:
# total 1320
# drwxr-xr-x 2 root root   4096 Apr  1 09:36 ./
# drwxr-xr-x 4 root root   4096 Apr  1 09:36 ../
# -rw-r--r-- 1 root root 163759 Apr  1 09:36 dog.jpg
# -rw-r--r-- 1 root root 141886 Apr  1 09:36 eagle.jpg
# -rw-r--r-- 1 root root 113880 Apr  1 09:36 field.jpg
# -rw-r--r-- 1 root root 382965 Apr  1 09:36 giraffe.jpg
# -rw-r--r-- 1 root root 133495 Apr  1 09:36 herd_of_horses.jpg
# -rw-r--r-- 1 root root 126867 Apr  1 09:36 messi.jpg
# -rw-r--r-- 1 root root  78771 Apr  1 09:36 person.jpg
# -rw-r--r-- 1 root root  84988 Apr  1 09:36 room.jpg
# -rw-r--r-- 1 root root 102770 Apr  1 09:36 street.jpg

# %% [markdown]
# - dog.jpg 파일을 가져와 실행해보겠습니다.

# %%
from IPython.display import Image
Image('/content/PyTorch-YOLOv3/data/samples/dog.jpg')

# %% [markdown]
# ## YOLOv3가 예측하여 사각형을 그린 이미지를 확인

# %%
ls -al /content/PyTorch-YOLOv3/output/
# Out:
# total 2564
# drwxr-xr-x  2 root root   4096 Apr  1 10:14 ./
# drwxr-xr-x 10 root root   4096 Apr  1 10:13 ../
# -rw-r--r--  1 root root 325667 Apr  1 10:14 dog.png
# -rw-r--r--  1 root root 302903 Apr  1 10:14 eagle.png
# -rw-r--r--  1 root root 299317 Apr  1 10:14 field.png
# -rw-r--r--  1 root root 379866 Apr  1 10:14 giraffe.png
# -rw-r--r--  1 root root 266355 Apr  1 10:14 herd_of_horses.png
# -rw-r--r--  1 root root 244507 Apr  1 10:14 messi.png
# -rw-r--r--  1 root root 179087 Apr  1 10:14 person.png
# -rw-r--r--  1 root root 308537 Apr  1 10:14 room.png
# -rw-r--r--  1 root root 293251 Apr  1 10:14 street.png

# %%
Image('/content/PyTorch-YOLOv3/output/dog.png')
